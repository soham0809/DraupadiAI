# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

def audio_to_spectrogram(audio_path, save_path):
    """
    Convert an audio file to a spectrogram and save it as a PNG.
    
    Args:
        audio_path (str): Path to the input audio file.
        save_path (str): Path to save the spectrogram image.
    """
    try:
        # Load the audio file
        y, sr = librosa.load(audio_path, sr=None)

        # Generate a Mel spectrogram
        mel_spect = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, fmax=8000)
        mel_spect_db = librosa.power_to_db(mel_spect, ref=np.max)

        # Plot the spectrogram
        plt.figure(figsize=(10, 4))
        librosa.display.specshow(mel_spect_db, sr=sr, x_axis='time', y_axis='mel', fmax=8000, cmap='viridis')
        plt.axis('off')  # Hide axes for cleaner images
        plt.tight_layout()

        # Save the plot as a PNG image
        plt.savefig(save_path, bbox_inches='tight', pad_inches=0)
        plt.close()
        print(f"Saved spectrogram: {save_path}")
    except Exception as e:
        print(f"Error processing {audio_path}: {e}")

# %%
import os

dataset_path = "dataset"
spectrograms_path = "spectrograms"

# Ensure the audio_to_spectrogram function is defined before calling
for label in ["scream", "non_scream"]:
    audio_files = os.listdir(os.path.join(dataset_path, label))
    for audio_file in audio_files:
        audio_path = os.path.join(dataset_path, label, audio_file)
        save_path = os.path.join(spectrograms_path, label, f"{audio_file.split('.')[0]}.png")
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        audio_to_spectrogram(audio_path, save_path)
# Out:
# Saved spectrogram: spectrograms\scream\1.png
# Saved spectrogram: spectrograms\scream\10.png
# Saved spectrogram: spectrograms\scream\100.png
# Saved spectrogram: spectrograms\scream\1000.png
# Saved spectrogram: spectrograms\scream\1001.png
# Saved spectrogram: spectrograms\scream\1002.png
# Saved spectrogram: spectrograms\scream\1003.png
# Saved spectrogram: spectrograms\scream\1004.png
# Saved spectrogram: spectrograms\scream\1005.png
# Saved spectrogram: spectrograms\scream\1006.png
# Saved spectrogram: spectrograms\scream\1007.png
# Saved spectrogram: spectrograms\scream\1008.png
# Saved spectrogram: spectrograms\scream\101.png
# Saved spectrogram: spectrograms\scream\1010.png
# Saved spectrogram: spectrograms\scream\1011.png
# Saved spectrogram: spectrograms\scream\1012.png
# Saved spectrogram: spectrograms\scream\1013.png
# Saved spectrogram: spectrograms\scream\1014.png
# Saved spectrogram: spectrograms\scream\1015.png
# Saved spectrogram: spectrograms\scream\1016.png
# Saved spectrogram: spectrograms\scream\1017.png
# Saved spectrogram: spectrograms\scream\1018.png
# Saved spectrogram: spectrograms\scream\1019.png
# Saved spectrogram: spectrograms\scream\102.png
# Saved spectrogram: spectrograms\scream\1020.png
# Saved spectrogram: spectrograms\scream\1021.png
# Saved spectrogram: spectrograms\scream\1022.png
# Saved spectrogram: spectrograms\scream\1023.png
# Saved spectrogram: spectrograms\scream\1024.png
# Saved spectrogram: spectrograms\scream\1025.png
# Saved spectrogram: spectrograms\scream\1026.png
# Saved spectrogram: spectrograms\scream\1027.png
# Saved spectrogram: spectrograms\scream\1028.png
# Saved spectrogram: spectrograms\scream\1029.png
# Saved spectrogram: spectrograms\scream\103.png
# Saved spectrogram: spectrograms\scream\1030.png
# Saved spectrogram: spectrograms\scream\1031.png
# Saved spectrogram: spectrograms\scream\1032.png
# Saved spectrogram: spectrograms\scream\1033.png
# Saved spectrogram: spectrograms\scream\1034.png
# Saved spectrogram: spectrograms\scream\1035.png
# Saved spectrogram: spectrograms\scream\1036.png
# Saved spectrogram: spectrograms\scream\1037.png
# Saved spectrogram: spectrograms\scream\1038.png
# Saved spectrogram: spectrograms\scream\1039.png
# Saved spectrogram: spectrograms\scream\104.png
# Saved spectrogram: spectrograms\scream\1040.png
# Saved spectrogram: spectrograms\scream\1041.png
# Saved spectrogram: spectrograms\scream\1042.png
# Saved spectrogram: spectrograms\scream\1043.png
# Saved spectrogram: spectrograms\scream\1044.png
# Saved spectrogram: spectrograms\scream\1045.png
# Saved spectrogram: spectrograms\scream\1046.png
# Saved spectrogram: spectrograms\scream\1047.png
# Saved spectrogram: spectrograms\scream\1048.png
# Saved spectrogram: spectrograms\scream\1049.png
# Saved spectrogram: spectrograms\scream\105.png
# Saved spectrogram: spectrograms\scream\1050.png
# Saved spectrogram: spectrograms\scream\1051.png
# Saved spectrogram: spectrograms\scream\1052.png
# Saved spectrogram: spectrograms\scream\1053.png
# Saved spectrogram: spectrograms\scream\1054.png
# Saved spectrogram: spectrograms\scream\1055.png
# Saved spectrogram: spectrograms\scream\1056.png
# Saved spectrogram: spectrograms\scream\1057.png
# Saved spectrogram: spectrograms\scream\1058.png
# Saved spectrogram: spectrograms\scream\1059.png
# Saved spectrogram: spectrograms\scream\106.png
# Saved spectrogram: spectrograms\scream\1060.png
# Saved spectrogram: spectrograms\scream\1061.png
# Saved spectrogram: spectrograms\scream\1062.png
# Saved spectrogram: spectrograms\scream\1063.png
# Saved spectrogram: spectrograms\scream\1064.png
# Saved spectrogram: spectrograms\scream\1065.png
# Saved spectrogram: spectrograms\scream\1066.png
# Saved spectrogram: spectrograms\scream\1067.png
# Saved spectrogram: spectrograms\scream\1068.png
# Saved spectrogram: spectrograms\scream\1069.png
# Saved spectrogram: spectrograms\scream\107.png
# Saved spectrogram: spectrograms\scream\1070.png
# Saved spectrogram: spectrograms\scream\1071.png
# Saved spectrogram: spectrograms\scream\1072.png
# Saved spectrogram: spectrograms\scream\1073.png
# Saved spectrogram: spectrograms\scream\1074.png
# Saved spectrogram: spectrograms\scream\1075.png
# Saved spectrogram: spectrograms\scream\1076.png
# Saved spectrogram: spectrograms\scream\1077.png
# Saved spectrogram: spectrograms\scream\1078.png
# Saved spectrogram: spectrograms\scream\1079.png
# Saved spectrogram: spectrograms\scream\108.png
# Saved spectrogram: spectrograms\scream\1080.png
# Saved spectrogram: spectrograms\scream\1081.png
# Saved spectrogram: spectrograms\scream\1082.png
# Saved spectrogram: spectrograms\scream\1083.png
# Saved spectrogram: spectrograms\scream\1084.png
# Saved spectrogram: spectrograms\scream\1085.png
# Saved spectrogram: spectrograms\scream\1086.png
# Saved spectrogram: spectrograms\scream\1087.png
# Saved spectrogram: spectrograms\scream\1088.png
# Saved spectrogram: spectrograms\scream\1089.png
# Saved spectrogram: spectrograms\scream\109.png
# Saved spectrogram: spectrograms\scream\1090.png
# Saved spectrogram: spectrograms\scream\1091.png
# Saved spectrogram: spectrograms\scream\1092.png
# Saved spectrogram: spectrograms\scream\1093.png
# Saved spectrogram: spectrograms\scream\1094.png
# Saved spectrogram: spectrograms\scream\1095.png
# Saved spectrogram: spectrograms\scream\1096.png
# Saved spectrogram: spectrograms\scream\1097.png
# Saved spectrogram: spectrograms\scream\1098.png
# Saved spectrogram: spectrograms\scream\1099.png
# Saved spectrogram: spectrograms\scream\11.png
# Saved spectrogram: spectrograms\scream\110.png
# Saved spectrogram: spectrograms\scream\1100.png
# Saved spectrogram: spectrograms\scream\1101.png
# Saved spectrogram: spectrograms\scream\1102.png
# Saved spectrogram: spectrograms\scream\1103.png
# Saved spectrogram: spectrograms\scream\1104.png
# Saved spectrogram: spectrograms\scream\1105.png
# Saved spectrogram: spectrograms\scream\1106.png
# Saved spectrogram: spectrograms\scream\1107.png
# Saved spectrogram: spectrograms\scream\1108.png
# Saved spectrogram: spectrograms\scream\1109.png
# Saved spectrogram: spectrograms\scream\111.png
# Saved spectrogram: spectrograms\scream\1110.png
# Saved spectrogram: spectrograms\scream\1111.png
# Saved spectrogram: spectrograms\scream\1112.png
# Saved spectrogram: spectrograms\scream\1113.png
# Saved spectrogram: spectrograms\scream\1114.png
# Saved spectrogram: spectrograms\scream\1115.png
# Saved spectrogram: spectrograms\scream\1116.png
# Saved spectrogram: spectrograms\scream\1117.png
# Saved spectrogram: spectrograms\scream\1118.png
# Saved spectrogram: spectrograms\scream\1119.png
# Saved spectrogram: spectrograms\scream\112.png
# Saved spectrogram: spectrograms\scream\1120.png
# Saved spectrogram: spectrograms\scream\1121.png
# Saved spectrogram: spectrograms\scream\1122.png
# Saved spectrogram: spectrograms\scream\1123.png
# Saved spectrogram: spectrograms\scream\1124.png
# Saved spectrogram: spectrograms\scream\1125.png
# Saved spectrogram: spectrograms\scream\1126.png
# Saved spectrogram: spectrograms\scream\1127.png
# Saved spectrogram: spectrograms\scream\1128.png
# Saved spectrogram: spectrograms\scream\1129.png
# Saved spectrogram: spectrograms\scream\113.png
# Saved spectrogram: spectrograms\scream\1130.png
# Saved spectrogram: spectrograms\scream\1131.png
# Saved spectrogram: spectrograms\scream\1132.png
# Saved spectrogram: spectrograms\scream\1133.png
# Saved spectrogram: spectrograms\scream\1134.png
# Saved spectrogram: spectrograms\scream\1135.png
# Saved spectrogram: spectrograms\scream\1136.png
# Saved spectrogram: spectrograms\scream\1137.png
# Saved spectrogram: spectrograms\scream\1138.png
# Saved spectrogram: spectrograms\scream\1139.png
# Saved spectrogram: spectrograms\scream\114.png
# Saved spectrogram: spectrograms\scream\1140.png
# Saved spectrogram: spectrograms\scream\1141.png
# Saved spectrogram: spectrograms\scream\1142.png
# Saved spectrogram: spectrograms\scream\1143.png
# Saved spectrogram: spectrograms\scream\1144.png
# Saved spectrogram: spectrograms\scream\1145.png
# Saved spectrogram: spectrograms\scream\1146.png
# Saved spectrogram: spectrograms\scream\1147.png
# Saved spectrogram: spectrograms\scream\1148.png
# Saved spectrogram: spectrograms\scream\1149.png
# Saved spectrogram: spectrograms\scream\115.png
# Saved spectrogram: spectrograms\scream\1150.png
# Saved spectrogram: spectrograms\scream\1151.png
# Saved spectrogram: spectrograms\scream\1152.png
# Saved spectrogram: spectrograms\scream\1153.png
# Saved spectrogram: spectrograms\scream\1154.png
# Saved spectrogram: spectrograms\scream\1155.png
# Saved spectrogram: spectrograms\scream\1156.png
# Saved spectrogram: spectrograms\scream\1157.png
# Saved spectrogram: spectrograms\scream\1158.png
# Saved spectrogram: spectrograms\scream\1159.png
# Saved spectrogram: spectrograms\scream\116.png
# Saved spectrogram: spectrograms\scream\1160.png
# Saved spectrogram: spectrograms\scream\1161.png
# Saved spectrogram: spectrograms\scream\1162.png
# Saved spectrogram: spectrograms\scream\1163.png
# Saved spectrogram: spectrograms\scream\1164.png
# Saved spectrogram: spectrograms\scream\1165.png
# Saved spectrogram: spectrograms\scream\1166.png
# Saved spectrogram: spectrograms\scream\1167.png
# Saved spectrogram: spectrograms\scream\1168.png
# Saved spectrogram: spectrograms\scream\1169.png
# Saved spectrogram: spectrograms\scream\117.png
# Saved spectrogram: spectrograms\scream\1170.png
# Saved spectrogram: spectrograms\scream\1171.png
# Saved spectrogram: spectrograms\scream\1172.png
# Saved spectrogram: spectrograms\scream\1173.png
# Saved spectrogram: spectrograms\scream\1174.png
# Saved spectrogram: spectrograms\scream\1175.png
# Saved spectrogram: spectrograms\scream\1176.png
# Saved spectrogram: spectrograms\scream\1177.png
# Saved spectrogram: spectrograms\scream\1178.png
# Saved spectrogram: spectrograms\scream\1179.png
# Saved spectrogram: spectrograms\scream\118.png
# Saved spectrogram: spectrograms\scream\1180.png
# Saved spectrogram: spectrograms\scream\1181.png
# Saved spectrogram: spectrograms\scream\1182.png
# Saved spectrogram: spectrograms\scream\1183.png
# Saved spectrogram: spectrograms\scream\1184.png
# Saved spectrogram: spectrograms\scream\1185.png
# Saved spectrogram: spectrograms\scream\1186.png
# Saved spectrogram: spectrograms\scream\1187.png
# Saved spectrogram: spectrograms\scream\1188.png
# Saved spectrogram: spectrograms\scream\1189.png
# Saved spectrogram: spectrograms\scream\119.png
# Saved spectrogram: spectrograms\scream\1190.png
# Saved spectrogram: spectrograms\scream\1191.png
# Saved spectrogram: spectrograms\scream\1192.png
# Saved spectrogram: spectrograms\scream\1193.png
# Saved spectrogram: spectrograms\scream\1194.png
# Saved spectrogram: spectrograms\scream\1195.png
# Saved spectrogram: spectrograms\scream\1196.png
# Saved spectrogram: spectrograms\scream\1197.png
# Saved spectrogram: spectrograms\scream\1198.png
# Saved spectrogram: spectrograms\scream\1199.png
# Saved spectrogram: spectrograms\scream\12.png
# Saved spectrogram: spectrograms\scream\120.png
# Saved spectrogram: spectrograms\scream\1200.png
# Saved spectrogram: spectrograms\scream\1201.png
# Saved spectrogram: spectrograms\scream\1202.png
# Saved spectrogram: spectrograms\scream\1203.png
# Saved spectrogram: spectrograms\scream\1204.png
# Saved spectrogram: spectrograms\scream\1205.png
# Saved spectrogram: spectrograms\scream\1206.png
# Saved spectrogram: spectrograms\scream\1207.png
# Saved spectrogram: spectrograms\scream\1208.png
# Saved spectrogram: spectrograms\scream\1209.png
# Saved spectrogram: spectrograms\scream\121.png
# Saved spectrogram: spectrograms\scream\1210.png
# Saved spectrogram: spectrograms\scream\1211.png
# Saved spectrogram: spectrograms\scream\1212.png
# Saved spectrogram: spectrograms\scream\1213.png
# Saved spectrogram: spectrograms\scream\1214.png
# Saved spectrogram: spectrograms\scream\1215.png
# Saved spectrogram: spectrograms\scream\1216.png
# Saved spectrogram: spectrograms\scream\1217.png
# Saved spectrogram: spectrograms\scream\1218.png
# Saved spectrogram: spectrograms\scream\1219.png
# Saved spectrogram: spectrograms\scream\122.png
# Saved spectrogram: spectrograms\scream\1220.png
# Saved spectrogram: spectrograms\scream\1221.png
# Saved spectrogram: spectrograms\scream\1222.png
# Saved spectrogram: spectrograms\scream\1223.png
# Saved spectrogram: spectrograms\scream\1224.png
# Saved spectrogram: spectrograms\scream\1225.png
# Saved spectrogram: spectrograms\scream\1226.png
# Saved spectrogram: spectrograms\scream\1227.png
# Saved spectrogram: spectrograms\scream\1228.png
# Saved spectrogram: spectrograms\scream\1229.png
# Saved spectrogram: spectrograms\scream\123.png
# Saved spectrogram: spectrograms\scream\1230.png
# Saved spectrogram: spectrograms\scream\1231.png
# Saved spectrogram: spectrograms\scream\1232.png
# Saved spectrogram: spectrograms\scream\1233.png
# Saved spectrogram: spectrograms\scream\1234.png
# Saved spectrogram: spectrograms\scream\1235.png
# Saved spectrogram: spectrograms\scream\1236.png
# Saved spectrogram: spectrograms\scream\1237.png
# Saved spectrogram: spectrograms\scream\1238.png
# Saved spectrogram: spectrograms\scream\1239.png
# Saved spectrogram: spectrograms\scream\124.png
# Saved spectrogram: spectrograms\scream\1240.png
# Saved spectrogram: spectrograms\scream\1241.png
# Saved spectrogram: spectrograms\scream\1242.png
# Saved spectrogram: spectrograms\scream\1243.png
# Saved spectrogram: spectrograms\scream\1244.png
# Saved spectrogram: spectrograms\scream\1245.png
# Saved spectrogram: spectrograms\scream\1246.png
# Saved spectrogram: spectrograms\scream\1247.png
# Saved spectrogram: spectrograms\scream\1248.png
# Saved spectrogram: spectrograms\scream\1249.png
# Saved spectrogram: spectrograms\scream\125.png
# Saved spectrogram: spectrograms\scream\1250.png
# Saved spectrogram: spectrograms\scream\1251.png
# Saved spectrogram: spectrograms\scream\1252.png
# Saved spectrogram: spectrograms\scream\1253.png
# Saved spectrogram: spectrograms\scream\1254.png
# Saved spectrogram: spectrograms\scream\1255.png
# Saved spectrogram: spectrograms\scream\1256.png
# Saved spectrogram: spectrograms\scream\1257.png
# Saved spectrogram: spectrograms\scream\1258.png
# Saved spectrogram: spectrograms\scream\1259.png
# Saved spectrogram: spectrograms\scream\126.png
# Saved spectrogram: spectrograms\scream\1260.png
# Saved spectrogram: spectrograms\scream\1261.png
# Saved spectrogram: spectrograms\scream\1262.png
# Saved spectrogram: spectrograms\scream\1263.png
# Saved spectrogram: spectrograms\scream\1264.png
# Saved spectrogram: spectrograms\scream\1265.png
# Saved spectrogram: spectrograms\scream\1266.png
# Saved spectrogram: spectrograms\scream\1267.png
# Saved spectrogram: spectrograms\scream\1268.png
# Saved spectrogram: spectrograms\scream\1269.png
# Saved spectrogram: spectrograms\scream\127.png
# Saved spectrogram: spectrograms\scream\1270.png
# Saved spectrogram: spectrograms\scream\1271.png
# Saved spectrogram: spectrograms\scream\1272.png
# Saved spectrogram: spectrograms\scream\1273.png
# Saved spectrogram: spectrograms\scream\1274.png
# Saved spectrogram: spectrograms\scream\1275.png
# Saved spectrogram: spectrograms\scream\1276.png
# Saved spectrogram: spectrograms\scream\1277.png
# Saved spectrogram: spectrograms\scream\1278.png
# Saved spectrogram: spectrograms\scream\1279.png
# Saved spectrogram: spectrograms\scream\128.png
# Saved spectrogram: spectrograms\scream\1280.png
# Saved spectrogram: spectrograms\scream\1281.png
# Saved spectrogram: spectrograms\scream\1282.png
# Saved spectrogram: spectrograms\scream\1283.png
# Saved spectrogram: spectrograms\scream\1284.png
# Saved spectrogram: spectrograms\scream\1285.png
# Saved spectrogram: spectrograms\scream\1286.png
# Saved spectrogram: spectrograms\scream\1287.png
# Saved spectrogram: spectrograms\scream\1288.png
# Saved spectrogram: spectrograms\scream\1289.png
# Saved spectrogram: spectrograms\scream\129.png
# Saved spectrogram: spectrograms\scream\1290.png
# Saved spectrogram: spectrograms\scream\1291.png
# Saved spectrogram: spectrograms\scream\1292.png
# Saved spectrogram: spectrograms\scream\1293.png
# Saved spectrogram: spectrograms\scream\1294.png
# Saved spectrogram: spectrograms\scream\1295.png
# Saved spectrogram: spectrograms\scream\1296.png
# Saved spectrogram: spectrograms\scream\1297.png
# Saved spectrogram: spectrograms\scream\1298.png
# Saved spectrogram: spectrograms\scream\1299.png
# Saved spectrogram: spectrograms\scream\13.png
# Saved spectrogram: spectrograms\scream\130.png
# Saved spectrogram: spectrograms\scream\1300.png
# Saved spectrogram: spectrograms\scream\1301.png
# Saved spectrogram: spectrograms\scream\1302.png
# Saved spectrogram: spectrograms\scream\1303.png
# Saved spectrogram: spectrograms\scream\1304.png
# Saved spectrogram: spectrograms\scream\1305.png
# Saved spectrogram: spectrograms\scream\1306.png
# Saved spectrogram: spectrograms\scream\1307.png
# Saved spectrogram: spectrograms\scream\1308.png
# Saved spectrogram: spectrograms\scream\1309.png
# Saved spectrogram: spectrograms\scream\131.png
# Saved spectrogram: spectrograms\scream\1310.png
# Saved spectrogram: spectrograms\scream\1311.png
# Saved spectrogram: spectrograms\scream\1312.png
# Saved spectrogram: spectrograms\scream\1313.png
# Saved spectrogram: spectrograms\scream\1314.png
# Saved spectrogram: spectrograms\scream\1315.png
# Saved spectrogram: spectrograms\scream\1316.png
# Saved spectrogram: spectrograms\scream\1317.png
# Saved spectrogram: spectrograms\scream\1318.png
# Saved spectrogram: spectrograms\scream\1319.png
# Saved spectrogram: spectrograms\scream\132.png
# Saved spectrogram: spectrograms\scream\1320.png
# Saved spectrogram: spectrograms\scream\1321.png
# Saved spectrogram: spectrograms\scream\1322.png
# Saved spectrogram: spectrograms\scream\1323.png
# Saved spectrogram: spectrograms\scream\1324.png
# Saved spectrogram: spectrograms\scream\1325.png
# Saved spectrogram: spectrograms\scream\1326.png
# Saved spectrogram: spectrograms\scream\1327.png
# Saved spectrogram: spectrograms\scream\1328.png
# Saved spectrogram: spectrograms\scream\1329.png
# Saved spectrogram: spectrograms\scream\133.png
# Saved spectrogram: spectrograms\scream\1330.png
# Saved spectrogram: spectrograms\scream\1331.png
# Saved spectrogram: spectrograms\scream\1332.png
# Saved spectrogram: spectrograms\scream\1333.png
# Saved spectrogram: spectrograms\scream\1334.png
# Saved spectrogram: spectrograms\scream\1335.png
# Saved spectrogram: spectrograms\scream\1336.png
# Saved spectrogram: spectrograms\scream\1337.png
# Saved spectrogram: spectrograms\scream\1338.png
# Saved spectrogram: spectrograms\scream\1339.png
# Saved spectrogram: spectrograms\scream\134.png
# Saved spectrogram: spectrograms\scream\1340.png
# Saved spectrogram: spectrograms\scream\1341.png
# Saved spectrogram: spectrograms\scream\1342.png
# Saved spectrogram: spectrograms\scream\1343.png
# Saved spectrogram: spectrograms\scream\1344.png
# Saved spectrogram: spectrograms\scream\1345.png
# Saved spectrogram: spectrograms\scream\1346.png
# Saved spectrogram: spectrograms\scream\1347.png
# Saved spectrogram: spectrograms\scream\1348.png
# Saved spectrogram: spectrograms\scream\1349.png
# Saved spectrogram: spectrograms\scream\135.png
# Saved spectrogram: spectrograms\scream\1350.png
# Saved spectrogram: spectrograms\scream\1351.png
# Saved spectrogram: spectrograms\scream\1352.png
# Saved spectrogram: spectrograms\scream\1353.png
# Saved spectrogram: spectrograms\scream\1354.png
# Saved spectrogram: spectrograms\scream\1355.png
# Saved spectrogram: spectrograms\scream\1356.png
# Saved spectrogram: spectrograms\scream\1357.png
# Saved spectrogram: spectrograms\scream\1358.png
# Saved spectrogram: spectrograms\scream\1359.png
# Saved spectrogram: spectrograms\scream\136.png
# Saved spectrogram: spectrograms\scream\1360.png
# Saved spectrogram: spectrograms\scream\1361.png
# Saved spectrogram: spectrograms\scream\1362.png
# Saved spectrogram: spectrograms\scream\1363.png
# Saved spectrogram: spectrograms\scream\1364.png
# Saved spectrogram: spectrograms\scream\1365.png
# Saved spectrogram: spectrograms\scream\1366.png
# Saved spectrogram: spectrograms\scream\1367.png
# Saved spectrogram: spectrograms\scream\1368.png
# Saved spectrogram: spectrograms\scream\1369.png
# Saved spectrogram: spectrograms\scream\137.png
# Saved spectrogram: spectrograms\scream\1370.png
# Saved spectrogram: spectrograms\scream\1371.png
# Saved spectrogram: spectrograms\scream\1372.png
# Saved spectrogram: spectrograms\scream\1373.png
# Saved spectrogram: spectrograms\scream\1374.png
# Saved spectrogram: spectrograms\scream\1375.png
# Saved spectrogram: spectrograms\scream\1376.png
# Saved spectrogram: spectrograms\scream\1377.png
# Saved spectrogram: spectrograms\scream\1378.png
# Saved spectrogram: spectrograms\scream\1379.png
# Saved spectrogram: spectrograms\scream\138.png
# Saved spectrogram: spectrograms\scream\1380.png
# Saved spectrogram: spectrograms\scream\1381.png
# Saved spectrogram: spectrograms\scream\1382.png
# Saved spectrogram: spectrograms\scream\1383.png
# Saved spectrogram: spectrograms\scream\1384.png
# Saved spectrogram: spectrograms\scream\1385.png
# Saved spectrogram: spectrograms\scream\1386.png
# Saved spectrogram: spectrograms\scream\1387.png
# Saved spectrogram: spectrograms\scream\1388.png
# Saved spectrogram: spectrograms\scream\1389.png
# Saved spectrogram: spectrograms\scream\139.png
# Saved spectrogram: spectrograms\scream\1390.png
# Saved spectrogram: spectrograms\scream\1391.png
# Saved spectrogram: spectrograms\scream\1392.png
# Saved spectrogram: spectrograms\scream\1393.png
# Saved spectrogram: spectrograms\scream\1394.png
# Saved spectrogram: spectrograms\scream\1395.png
# Saved spectrogram: spectrograms\scream\1396.png
# Saved spectrogram: spectrograms\scream\1397.png
# Saved spectrogram: spectrograms\scream\1398.png
# Saved spectrogram: spectrograms\scream\1399.png
# Saved spectrogram: spectrograms\scream\14.png
# Saved spectrogram: spectrograms\scream\140.png
# Saved spectrogram: spectrograms\scream\1400.png
# Saved spectrogram: spectrograms\scream\1401.png
# Saved spectrogram: spectrograms\scream\1402.png
# Saved spectrogram: spectrograms\scream\1403.png
# Saved spectrogram: spectrograms\scream\1404.png
# Saved spectrogram: spectrograms\scream\1405.png
# Saved spectrogram: spectrograms\scream\1406.png
# Saved spectrogram: spectrograms\scream\1407.png
# Saved spectrogram: spectrograms\scream\1408.png
# Saved spectrogram: spectrograms\scream\1409.png
# Saved spectrogram: spectrograms\scream\141.png
# Saved spectrogram: spectrograms\scream\1410.png
# Saved spectrogram: spectrograms\scream\1411.png
# Saved spectrogram: spectrograms\scream\1412.png
# Saved spectrogram: spectrograms\scream\1413.png
# Saved spectrogram: spectrograms\scream\1414.png
# Saved spectrogram: spectrograms\scream\1415.png
# Saved spectrogram: spectrograms\scream\1416.png
# Saved spectrogram: spectrograms\scream\1417.png
# Saved spectrogram: spectrograms\scream\1418.png
# Saved spectrogram: spectrograms\scream\1419.png
# Saved spectrogram: spectrograms\scream\142.png
# Saved spectrogram: spectrograms\scream\1420.png
# Saved spectrogram: spectrograms\scream\1421.png
# Saved spectrogram: spectrograms\scream\1422.png
# Saved spectrogram: spectrograms\scream\1423.png
# Saved spectrogram: spectrograms\scream\1424.png
# Saved spectrogram: spectrograms\scream\1425.png
# Saved spectrogram: spectrograms\scream\1426.png
# Saved spectrogram: spectrograms\scream\1427.png
# Saved spectrogram: spectrograms\scream\1428.png
# Saved spectrogram: spectrograms\scream\1429.png
# Saved spectrogram: spectrograms\scream\143.png
# Saved spectrogram: spectrograms\scream\1430.png
# Saved spectrogram: spectrograms\scream\1431.png
# Saved spectrogram: spectrograms\scream\1432.png
# Saved spectrogram: spectrograms\scream\1433.png
# Saved spectrogram: spectrograms\scream\1434.png
# Saved spectrogram: spectrograms\scream\1435.png
# Saved spectrogram: spectrograms\scream\1436.png
# Saved spectrogram: spectrograms\scream\1437.png
# Saved spectrogram: spectrograms\scream\1438.png
# Saved spectrogram: spectrograms\scream\1439.png
# Saved spectrogram: spectrograms\scream\144.png
# Saved spectrogram: spectrograms\scream\1440.png
# Saved spectrogram: spectrograms\scream\1441.png
# Saved spectrogram: spectrograms\scream\1442.png
# Saved spectrogram: spectrograms\scream\1443.png
# Saved spectrogram: spectrograms\scream\1444.png
# Saved spectrogram: spectrograms\scream\1445.png
# Saved spectrogram: spectrograms\scream\1446.png
# Saved spectrogram: spectrograms\scream\1447.png
# Saved spectrogram: spectrograms\scream\1448.png
# Saved spectrogram: spectrograms\scream\1449.png
# Saved spectrogram: spectrograms\scream\145.png
# Saved spectrogram: spectrograms\scream\1450.png
# Saved spectrogram: spectrograms\scream\1451.png
# Saved spectrogram: spectrograms\scream\1452.png
# Saved spectrogram: spectrograms\scream\1453.png
# Saved spectrogram: spectrograms\scream\1454.png
# Saved spectrogram: spectrograms\scream\1456.png
# Saved spectrogram: spectrograms\scream\1457.png
# Saved spectrogram: spectrograms\scream\1458.png
# Saved spectrogram: spectrograms\scream\1459.png
# Saved spectrogram: spectrograms\scream\146.png
# Saved spectrogram: spectrograms\scream\1460.png
# Saved spectrogram: spectrograms\scream\1461.png
# Saved spectrogram: spectrograms\scream\1462.png
# Saved spectrogram: spectrograms\scream\1463.png
# Saved spectrogram: spectrograms\scream\1464.png
# Saved spectrogram: spectrograms\scream\1465.png
# Saved spectrogram: spectrograms\scream\1466.png
# Saved spectrogram: spectrograms\scream\1467.png
# Saved spectrogram: spectrograms\scream\1468.png
# Saved spectrogram: spectrograms\scream\1469.png
# Saved spectrogram: spectrograms\scream\147.png
# Saved spectrogram: spectrograms\scream\1470.png
# Saved spectrogram: spectrograms\scream\1471.png
# Saved spectrogram: spectrograms\scream\1472.png
# Saved spectrogram: spectrograms\scream\1473.png
# Saved spectrogram: spectrograms\scream\1474.png
# Saved spectrogram: spectrograms\scream\1475.png
# Saved spectrogram: spectrograms\scream\1476.png
# Saved spectrogram: spectrograms\scream\1477.png
# Saved spectrogram: spectrograms\scream\1478.png
# Saved spectrogram: spectrograms\scream\1479.png
# Saved spectrogram: spectrograms\scream\148.png
# Saved spectrogram: spectrograms\scream\1480.png
# Saved spectrogram: spectrograms\scream\1481.png
# Saved spectrogram: spectrograms\scream\1482.png
# Saved spectrogram: spectrograms\scream\1483.png
# Saved spectrogram: spectrograms\scream\1484.png
# Saved spectrogram: spectrograms\scream\1485.png
# Saved spectrogram: spectrograms\scream\1486.png
# Saved spectrogram: spectrograms\scream\1487.png
# Saved spectrogram: spectrograms\scream\1488.png
# Saved spectrogram: spectrograms\scream\1489.png
# Saved spectrogram: spectrograms\scream\149.png
# Saved spectrogram: spectrograms\scream\1490.png
# Saved spectrogram: spectrograms\scream\1491.png
# Saved spectrogram: spectrograms\scream\1492.png
# Saved spectrogram: spectrograms\scream\1493.png
# Saved spectrogram: spectrograms\scream\1494.png
# Saved spectrogram: spectrograms\scream\1495.png
# Saved spectrogram: spectrograms\scream\1496.png
# Saved spectrogram: spectrograms\scream\1497.png
# Saved spectrogram: spectrograms\scream\1498.png
# Saved spectrogram: spectrograms\scream\1499.png
# Saved spectrogram: spectrograms\scream\15.png
# Saved spectrogram: spectrograms\scream\150.png
# Saved spectrogram: spectrograms\scream\1500.png
# Saved spectrogram: spectrograms\scream\1501.png
# Saved spectrogram: spectrograms\scream\1502.png
# Saved spectrogram: spectrograms\scream\1503.png
# Saved spectrogram: spectrograms\scream\1504.png
# Saved spectrogram: spectrograms\scream\1505.png
# Saved spectrogram: spectrograms\scream\1506.png
# Saved spectrogram: spectrograms\scream\1507.png
# Saved spectrogram: spectrograms\scream\1508.png
# Saved spectrogram: spectrograms\scream\1509.png
# Saved spectrogram: spectrograms\scream\151.png
# Saved spectrogram: spectrograms\scream\1510.png
# Saved spectrogram: spectrograms\scream\1511.png
# Saved spectrogram: spectrograms\scream\1512.png
# Saved spectrogram: spectrograms\scream\1513.png
# Saved spectrogram: spectrograms\scream\1514.png
# Saved spectrogram: spectrograms\scream\1515.png
# Saved spectrogram: spectrograms\scream\1516.png
# Saved spectrogram: spectrograms\scream\1517.png
# Saved spectrogram: spectrograms\scream\1518.png
# Saved spectrogram: spectrograms\scream\1519.png
# Saved spectrogram: spectrograms\scream\152.png
# Saved spectrogram: spectrograms\scream\1520.png
# Saved spectrogram: spectrograms\scream\1521.png
# Saved spectrogram: spectrograms\scream\1522.png
# Saved spectrogram: spectrograms\scream\1523.png
# Saved spectrogram: spectrograms\scream\1524.png
# Saved spectrogram: spectrograms\scream\1525.png
# Saved spectrogram: spectrograms\scream\1526.png
# Saved spectrogram: spectrograms\scream\1527.png
# Saved spectrogram: spectrograms\scream\1528.png
# Saved spectrogram: spectrograms\scream\1529.png
# Saved spectrogram: spectrograms\scream\153.png
# Saved spectrogram: spectrograms\scream\1530.png
# Saved spectrogram: spectrograms\scream\1531.png
# Saved spectrogram: spectrograms\scream\1532.png
# Saved spectrogram: spectrograms\scream\1533.png
# Saved spectrogram: spectrograms\scream\1534.png
# Saved spectrogram: spectrograms\scream\1535.png
# Saved spectrogram: spectrograms\scream\1536.png
# Saved spectrogram: spectrograms\scream\1537.png
# Saved spectrogram: spectrograms\scream\1538.png
# Saved spectrogram: spectrograms\scream\1539.png
# Saved spectrogram: spectrograms\scream\154.png
# Saved spectrogram: spectrograms\scream\1540.png
# Saved spectrogram: spectrograms\scream\1541.png
# Saved spectrogram: spectrograms\scream\1542.png
# Saved spectrogram: spectrograms\scream\1543.png
# Saved spectrogram: spectrograms\scream\1544.png
# Saved spectrogram: spectrograms\scream\1545.png
# Saved spectrogram: spectrograms\scream\1546.png
# Saved spectrogram: spectrograms\scream\1547.png
# Saved spectrogram: spectrograms\scream\1548.png
# Saved spectrogram: spectrograms\scream\1549.png
# Saved spectrogram: spectrograms\scream\155.png
# Saved spectrogram: spectrograms\scream\1550.png
# Saved spectrogram: spectrograms\scream\1551.png
# Saved spectrogram: spectrograms\scream\1552.png
# Saved spectrogram: spectrograms\scream\1553.png
# Saved spectrogram: spectrograms\scream\1554.png
# Saved spectrogram: spectrograms\scream\1555.png
# Saved spectrogram: spectrograms\scream\1556.png
# Saved spectrogram: spectrograms\scream\1557.png
# Saved spectrogram: spectrograms\scream\1558.png
# Saved spectrogram: spectrograms\scream\1559.png
# Saved spectrogram: spectrograms\scream\156.png
# Saved spectrogram: spectrograms\scream\1560.png
# Saved spectrogram: spectrograms\scream\1561.png
# Saved spectrogram: spectrograms\scream\1562.png
# Saved spectrogram: spectrograms\scream\1563.png
# Saved spectrogram: spectrograms\scream\1564.png
# Saved spectrogram: spectrograms\scream\1565.png
# Saved spectrogram: spectrograms\scream\1566.png
# Saved spectrogram: spectrograms\scream\1567.png
# Saved spectrogram: spectrograms\scream\1568.png
# Saved spectrogram: spectrograms\scream\1569.png
# Saved spectrogram: spectrograms\scream\157.png
# Saved spectrogram: spectrograms\scream\1570.png
# Saved spectrogram: spectrograms\scream\1571.png
# Saved spectrogram: spectrograms\scream\1572.png
# Saved spectrogram: spectrograms\scream\1573.png
# Saved spectrogram: spectrograms\scream\1574.png
# Saved spectrogram: spectrograms\scream\1575.png
# Saved spectrogram: spectrograms\scream\1576.png
# Saved spectrogram: spectrograms\scream\1577.png
# Saved spectrogram: spectrograms\scream\1578.png
# Saved spectrogram: spectrograms\scream\1579.png
# Saved spectrogram: spectrograms\scream\158.png
# Saved spectrogram: spectrograms\scream\1580.png
# Saved spectrogram: spectrograms\scream\1581.png
# Saved spectrogram: spectrograms\scream\1582.png
# Saved spectrogram: spectrograms\scream\1583.png
# Saved spectrogram: spectrograms\scream\1584.png
# Saved spectrogram: spectrograms\scream\1585.png
# Saved spectrogram: spectrograms\scream\1586.png
# Saved spectrogram: spectrograms\scream\159.png
# Saved spectrogram: spectrograms\scream\16.png
# Saved spectrogram: spectrograms\scream\160.png
# Saved spectrogram: spectrograms\scream\161.png
# Saved spectrogram: spectrograms\scream\162.png
# Saved spectrogram: spectrograms\scream\163.png
# Saved spectrogram: spectrograms\scream\164.png
# Saved spectrogram: spectrograms\scream\165.png
# Saved spectrogram: spectrograms\scream\166.png
# Saved spectrogram: spectrograms\scream\167.png
# Saved spectrogram: spectrograms\scream\168.png
# Saved spectrogram: spectrograms\scream\169.png
# Saved spectrogram: spectrograms\scream\17.png
# Saved spectrogram: spectrograms\scream\170.png
# Saved spectrogram: spectrograms\scream\171.png
# Saved spectrogram: spectrograms\scream\172.png
# Saved spectrogram: spectrograms\scream\173.png
# Saved spectrogram: spectrograms\scream\174.png
# Saved spectrogram: spectrograms\scream\175.png
# Saved spectrogram: spectrograms\scream\176.png
# Saved spectrogram: spectrograms\scream\177.png
# Saved spectrogram: spectrograms\scream\178.png
# Saved spectrogram: spectrograms\scream\179.png
# Saved spectrogram: spectrograms\scream\18.png
# Saved spectrogram: spectrograms\scream\180.png
# Saved spectrogram: spectrograms\scream\181.png
# Saved spectrogram: spectrograms\scream\182.png
# Saved spectrogram: spectrograms\scream\183.png
# Saved spectrogram: spectrograms\scream\184.png
# Saved spectrogram: spectrograms\scream\185.png
# Saved spectrogram: spectrograms\scream\186.png
# Saved spectrogram: spectrograms\scream\187.png
# Saved spectrogram: spectrograms\scream\188.png
# Saved spectrogram: spectrograms\scream\189.png
# Saved spectrogram: spectrograms\scream\19.png
# Saved spectrogram: spectrograms\scream\190.png
# Saved spectrogram: spectrograms\scream\191.png
# Saved spectrogram: spectrograms\scream\192.png
# Saved spectrogram: spectrograms\scream\193.png
# Saved spectrogram: spectrograms\scream\194.png
# Saved spectrogram: spectrograms\scream\195.png
# Saved spectrogram: spectrograms\scream\196.png
# Saved spectrogram: spectrograms\scream\197.png
# Saved spectrogram: spectrograms\scream\198.png
# Saved spectrogram: spectrograms\scream\199.png
# Saved spectrogram: spectrograms\scream\2.png
# Saved spectrogram: spectrograms\scream\20.png
# Saved spectrogram: spectrograms\scream\200.png
# Saved spectrogram: spectrograms\scream\201.png
# Saved spectrogram: spectrograms\scream\202.png
# Saved spectrogram: spectrograms\scream\203.png
# Saved spectrogram: spectrograms\scream\204.png
# Saved spectrogram: spectrograms\scream\205.png
# Saved spectrogram: spectrograms\scream\206.png
# Saved spectrogram: spectrograms\scream\207.png
# Saved spectrogram: spectrograms\scream\208.png
# Saved spectrogram: spectrograms\scream\209.png
# Saved spectrogram: spectrograms\scream\21.png
# Saved spectrogram: spectrograms\scream\210.png
# Saved spectrogram: spectrograms\scream\211.png
# Saved spectrogram: spectrograms\scream\212.png
# Saved spectrogram: spectrograms\scream\213.png
# Saved spectrogram: spectrograms\scream\214.png
# Saved spectrogram: spectrograms\scream\215.png
# Saved spectrogram: spectrograms\scream\216.png
# Saved spectrogram: spectrograms\scream\217.png
# Saved spectrogram: spectrograms\scream\218.png
# Saved spectrogram: spectrograms\scream\219.png
# Saved spectrogram: spectrograms\scream\22.png
# Saved spectrogram: spectrograms\scream\220.png
# Saved spectrogram: spectrograms\scream\221.png
# Saved spectrogram: spectrograms\scream\222.png
# Saved spectrogram: spectrograms\scream\223.png
# Saved spectrogram: spectrograms\scream\224.png
# Saved spectrogram: spectrograms\scream\225.png
# Saved spectrogram: spectrograms\scream\226.png
# Saved spectrogram: spectrograms\scream\227.png
# Saved spectrogram: spectrograms\scream\228.png
# Saved spectrogram: spectrograms\scream\229.png
# Saved spectrogram: spectrograms\scream\23.png
# Saved spectrogram: spectrograms\scream\230.png
# Saved spectrogram: spectrograms\scream\231.png
# Saved spectrogram: spectrograms\scream\232.png
# Saved spectrogram: spectrograms\scream\233.png
# Saved spectrogram: spectrograms\scream\234.png
# Saved spectrogram: spectrograms\scream\235.png
# Saved spectrogram: spectrograms\scream\236.png
# Saved spectrogram: spectrograms\scream\237.png
# Saved spectrogram: spectrograms\scream\238.png
# Saved spectrogram: spectrograms\scream\239.png
# Saved spectrogram: spectrograms\scream\24.png
# Saved spectrogram: spectrograms\scream\240.png
# Saved spectrogram: spectrograms\scream\241.png
# Saved spectrogram: spectrograms\scream\242.png
# Saved spectrogram: spectrograms\scream\243.png
# Saved spectrogram: spectrograms\scream\244.png
# Saved spectrogram: spectrograms\scream\245.png
# Saved spectrogram: spectrograms\scream\246.png
# Saved spectrogram: spectrograms\scream\247.png
# Saved spectrogram: spectrograms\scream\248.png
# Saved spectrogram: spectrograms\scream\249.png
# Saved spectrogram: spectrograms\scream\25.png
# Saved spectrogram: spectrograms\scream\250.png
# Saved spectrogram: spectrograms\scream\251.png
# Saved spectrogram: spectrograms\scream\252.png
# Saved spectrogram: spectrograms\scream\253.png
# Saved spectrogram: spectrograms\scream\254.png
# Saved spectrogram: spectrograms\scream\255.png
# Saved spectrogram: spectrograms\scream\256.png
# Saved spectrogram: spectrograms\scream\257.png
# Saved spectrogram: spectrograms\scream\258.png
# Saved spectrogram: spectrograms\scream\259.png
# Saved spectrogram: spectrograms\scream\26.png
# Saved spectrogram: spectrograms\scream\260.png
# Saved spectrogram: spectrograms\scream\261.png
# Saved spectrogram: spectrograms\scream\262.png
# Saved spectrogram: spectrograms\scream\263.png
# Saved spectrogram: spectrograms\scream\264.png
# Saved spectrogram: spectrograms\scream\265.png
# Saved spectrogram: spectrograms\scream\266.png
# Saved spectrogram: spectrograms\scream\267.png
# Saved spectrogram: spectrograms\scream\268.png
# Saved spectrogram: spectrograms\scream\269.png
# Saved spectrogram: spectrograms\scream\27.png
# Saved spectrogram: spectrograms\scream\270.png
# Saved spectrogram: spectrograms\scream\271.png
# Saved spectrogram: spectrograms\scream\272.png
# Saved spectrogram: spectrograms\scream\273.png
# Saved spectrogram: spectrograms\scream\274.png
# Saved spectrogram: spectrograms\scream\275.png
# Saved spectrogram: spectrograms\scream\276.png
# Saved spectrogram: spectrograms\scream\277.png
# Saved spectrogram: spectrograms\scream\278.png
# Saved spectrogram: spectrograms\scream\279.png
# Saved spectrogram: spectrograms\scream\28.png
# Saved spectrogram: spectrograms\scream\280.png
# Saved spectrogram: spectrograms\scream\281.png
# Saved spectrogram: spectrograms\scream\282.png
# Saved spectrogram: spectrograms\scream\283.png
# Saved spectrogram: spectrograms\scream\284.png
# Saved spectrogram: spectrograms\scream\285.png
# Saved spectrogram: spectrograms\scream\286.png
# Saved spectrogram: spectrograms\scream\287.png
# Saved spectrogram: spectrograms\scream\288.png
# Saved spectrogram: spectrograms\scream\289.png
# Saved spectrogram: spectrograms\scream\29.png
# Saved spectrogram: spectrograms\scream\290.png
# Saved spectrogram: spectrograms\scream\291.png
# Saved spectrogram: spectrograms\scream\292.png
# Saved spectrogram: spectrograms\scream\293.png
# Saved spectrogram: spectrograms\scream\294.png
# Saved spectrogram: spectrograms\scream\295.png
# Saved spectrogram: spectrograms\scream\296.png
# Saved spectrogram: spectrograms\scream\297.png
# Saved spectrogram: spectrograms\scream\298.png
# Saved spectrogram: spectrograms\scream\299.png
# Saved spectrogram: spectrograms\scream\3.png
# Saved spectrogram: spectrograms\scream\30.png
# Saved spectrogram: spectrograms\scream\300.png
# Saved spectrogram: spectrograms\scream\301.png
# Saved spectrogram: spectrograms\scream\302.png
# Saved spectrogram: spectrograms\scream\303.png
# Saved spectrogram: spectrograms\scream\304.png
# Saved spectrogram: spectrograms\scream\305.png
# Saved spectrogram: spectrograms\scream\306.png
# Saved spectrogram: spectrograms\scream\307.png
# Saved spectrogram: spectrograms\scream\308.png
# Saved spectrogram: spectrograms\scream\309.png
# Saved spectrogram: spectrograms\scream\31.png
# Saved spectrogram: spectrograms\scream\310.png
# Saved spectrogram: spectrograms\scream\311.png
# Saved spectrogram: spectrograms\scream\312.png
# Saved spectrogram: spectrograms\scream\313.png
# Saved spectrogram: spectrograms\scream\314.png
# Saved spectrogram: spectrograms\scream\315.png
# Saved spectrogram: spectrograms\scream\316.png
# Saved spectrogram: spectrograms\scream\317.png
# Saved spectrogram: spectrograms\scream\318.png
# Saved spectrogram: spectrograms\scream\319.png
# Saved spectrogram: spectrograms\scream\32.png
# Saved spectrogram: spectrograms\scream\320.png
# Saved spectrogram: spectrograms\scream\321.png
# Saved spectrogram: spectrograms\scream\322.png
# Saved spectrogram: spectrograms\scream\323.png
# Saved spectrogram: spectrograms\scream\324.png
# Saved spectrogram: spectrograms\scream\325.png
# Saved spectrogram: spectrograms\scream\326.png
# Saved spectrogram: spectrograms\scream\327.png
# Saved spectrogram: spectrograms\scream\328.png
# Saved spectrogram: spectrograms\scream\329.png
# Saved spectrogram: spectrograms\scream\33.png
# Saved spectrogram: spectrograms\scream\330.png
# Saved spectrogram: spectrograms\scream\331.png
# Saved spectrogram: spectrograms\scream\332.png
# Saved spectrogram: spectrograms\scream\333.png
# Saved spectrogram: spectrograms\scream\334.png
# Saved spectrogram: spectrograms\scream\335.png
# Saved spectrogram: spectrograms\scream\336.png
# Saved spectrogram: spectrograms\scream\337.png
# Saved spectrogram: spectrograms\scream\338.png
# Saved spectrogram: spectrograms\scream\339.png
# Saved spectrogram: spectrograms\scream\34.png
# Saved spectrogram: spectrograms\scream\340.png
# Saved spectrogram: spectrograms\scream\341.png
# Saved spectrogram: spectrograms\scream\342.png
# Saved spectrogram: spectrograms\scream\343.png
# Saved spectrogram: spectrograms\scream\344.png
# Saved spectrogram: spectrograms\scream\345.png
# Saved spectrogram: spectrograms\scream\346.png
# Saved spectrogram: spectrograms\scream\347.png
# Saved spectrogram: spectrograms\scream\348.png
# Saved spectrogram: spectrograms\scream\349.png
# Saved spectrogram: spectrograms\scream\35.png
# Saved spectrogram: spectrograms\scream\350.png
# Saved spectrogram: spectrograms\scream\351.png
# Saved spectrogram: spectrograms\scream\352.png
# Saved spectrogram: spectrograms\scream\353.png
# Saved spectrogram: spectrograms\scream\354.png
# Saved spectrogram: spectrograms\scream\355.png
# Saved spectrogram: spectrograms\scream\356.png
# Saved spectrogram: spectrograms\scream\357.png
# Saved spectrogram: spectrograms\scream\358.png
# Saved spectrogram: spectrograms\scream\359.png
# Saved spectrogram: spectrograms\scream\36.png
# Saved spectrogram: spectrograms\scream\360.png
# Saved spectrogram: spectrograms\scream\361.png
# Saved spectrogram: spectrograms\scream\362.png
# Saved spectrogram: spectrograms\scream\363.png
# Saved spectrogram: spectrograms\scream\364.png
# Saved spectrogram: spectrograms\scream\365.png
# Saved spectrogram: spectrograms\scream\366.png
# Saved spectrogram: spectrograms\scream\367.png
# Saved spectrogram: spectrograms\scream\368.png
# Saved spectrogram: spectrograms\scream\369.png
# Saved spectrogram: spectrograms\scream\37.png
# Saved spectrogram: spectrograms\scream\370.png
# Saved spectrogram: spectrograms\scream\371.png
# Saved spectrogram: spectrograms\scream\372.png
# Saved spectrogram: spectrograms\scream\373.png
# Saved spectrogram: spectrograms\scream\374.png
# Saved spectrogram: spectrograms\scream\375.png
# Saved spectrogram: spectrograms\scream\376.png
# Saved spectrogram: spectrograms\scream\377.png
# Saved spectrogram: spectrograms\scream\378.png
# Saved spectrogram: spectrograms\scream\379.png
# Saved spectrogram: spectrograms\scream\38.png
# Saved spectrogram: spectrograms\scream\380.png
# Saved spectrogram: spectrograms\scream\381.png
# Saved spectrogram: spectrograms\scream\382.png
# Saved spectrogram: spectrograms\scream\383.png
# Saved spectrogram: spectrograms\scream\384.png
# Saved spectrogram: spectrograms\scream\385.png
# Saved spectrogram: spectrograms\scream\386.png
# Saved spectrogram: spectrograms\scream\387.png
# Saved spectrogram: spectrograms\scream\388.png
# Saved spectrogram: spectrograms\scream\389.png
# Saved spectrogram: spectrograms\scream\39.png
# Saved spectrogram: spectrograms\scream\390.png
# Saved spectrogram: spectrograms\scream\391.png
# Saved spectrogram: spectrograms\scream\392.png
# Saved spectrogram: spectrograms\scream\393.png
# Saved spectrogram: spectrograms\scream\394.png
# Saved spectrogram: spectrograms\scream\395.png
# Saved spectrogram: spectrograms\scream\396.png
# Saved spectrogram: spectrograms\scream\397.png
# Saved spectrogram: spectrograms\scream\398.png
# Saved spectrogram: spectrograms\scream\399.png
# Saved spectrogram: spectrograms\scream\4.png
# Saved spectrogram: spectrograms\scream\40.png
# Saved spectrogram: spectrograms\scream\400.png
# Saved spectrogram: spectrograms\scream\401.png
# Saved spectrogram: spectrograms\scream\402.png
# Saved spectrogram: spectrograms\scream\403.png
# Saved spectrogram: spectrograms\scream\404.png
# Saved spectrogram: spectrograms\scream\405.png
# Saved spectrogram: spectrograms\scream\406.png
# Saved spectrogram: spectrograms\scream\407.png
# Saved spectrogram: spectrograms\scream\408.png
# Saved spectrogram: spectrograms\scream\409.png
# Saved spectrogram: spectrograms\scream\41.png
# Saved spectrogram: spectrograms\scream\410.png
# Saved spectrogram: spectrograms\scream\411.png
# Saved spectrogram: spectrograms\scream\412.png
# Saved spectrogram: spectrograms\scream\413.png
# Saved spectrogram: spectrograms\scream\414.png
# Saved spectrogram: spectrograms\scream\415.png
# Saved spectrogram: spectrograms\scream\416.png
# Saved spectrogram: spectrograms\scream\417.png
# Saved spectrogram: spectrograms\scream\418.png
# Saved spectrogram: spectrograms\scream\419.png
# Saved spectrogram: spectrograms\scream\42.png
# Saved spectrogram: spectrograms\scream\420.png
# Saved spectrogram: spectrograms\scream\421.png
# Saved spectrogram: spectrograms\scream\422.png
# Saved spectrogram: spectrograms\scream\423.png
# Saved spectrogram: spectrograms\scream\424.png
# Saved spectrogram: spectrograms\scream\425.png
# Saved spectrogram: spectrograms\scream\426.png
# Saved spectrogram: spectrograms\scream\427.png
# Saved spectrogram: spectrograms\scream\428.png
# Saved spectrogram: spectrograms\scream\429.png
# Saved spectrogram: spectrograms\scream\43.png
# Saved spectrogram: spectrograms\scream\430.png
# Saved spectrogram: spectrograms\scream\431.png
# Saved spectrogram: spectrograms\scream\432.png
# Saved spectrogram: spectrograms\scream\433.png
# Saved spectrogram: spectrograms\scream\434.png
# Saved spectrogram: spectrograms\scream\435.png
# Saved spectrogram: spectrograms\scream\436.png
# Saved spectrogram: spectrograms\scream\437.png
# Saved spectrogram: spectrograms\scream\438.png
# Saved spectrogram: spectrograms\scream\439.png
# Saved spectrogram: spectrograms\scream\44.png
# Saved spectrogram: spectrograms\scream\440.png
# Saved spectrogram: spectrograms\scream\441.png
# Saved spectrogram: spectrograms\scream\442.png
# Saved spectrogram: spectrograms\scream\443.png
# Saved spectrogram: spectrograms\scream\444.png
# Saved spectrogram: spectrograms\scream\445.png
# Saved spectrogram: spectrograms\scream\446.png
# Saved spectrogram: spectrograms\scream\447.png
# Saved spectrogram: spectrograms\scream\448.png
# Saved spectrogram: spectrograms\scream\449.png
# Saved spectrogram: spectrograms\scream\45.png
# Saved spectrogram: spectrograms\scream\450.png
# Saved spectrogram: spectrograms\scream\451.png
# Saved spectrogram: spectrograms\scream\452.png
# Saved spectrogram: spectrograms\scream\453.png
# Saved spectrogram: spectrograms\scream\454.png
# Saved spectrogram: spectrograms\scream\455.png
# Saved spectrogram: spectrograms\scream\456.png
# Saved spectrogram: spectrograms\scream\457.png
# Saved spectrogram: spectrograms\scream\458.png
# Saved spectrogram: spectrograms\scream\459.png
# Saved spectrogram: spectrograms\scream\46.png
# Saved spectrogram: spectrograms\scream\460.png
# Saved spectrogram: spectrograms\scream\461.png
# Saved spectrogram: spectrograms\scream\462.png
# Saved spectrogram: spectrograms\scream\463.png
# Saved spectrogram: spectrograms\scream\464.png
# Saved spectrogram: spectrograms\scream\465.png
# Saved spectrogram: spectrograms\scream\466.png
# Saved spectrogram: spectrograms\scream\467.png
# Saved spectrogram: spectrograms\scream\468.png
# Saved spectrogram: spectrograms\scream\469.png
# Saved spectrogram: spectrograms\scream\47.png
# Saved spectrogram: spectrograms\scream\470.png
# Saved spectrogram: spectrograms\scream\471.png
# Saved spectrogram: spectrograms\scream\472.png
# Saved spectrogram: spectrograms\scream\473.png
# Saved spectrogram: spectrograms\scream\474.png
# Saved spectrogram: spectrograms\scream\475.png
# Saved spectrogram: spectrograms\scream\476.png
# Saved spectrogram: spectrograms\scream\477.png
# Saved spectrogram: spectrograms\scream\478.png
# Saved spectrogram: spectrograms\scream\479.png
# Saved spectrogram: spectrograms\scream\48.png
# Saved spectrogram: spectrograms\scream\480.png
# ...
# Saved spectrogram: spectrograms\non_scream\676.png
# Saved spectrogram: spectrograms\non_scream\677.png
# Saved spectrogram: spectrograms\non_scream\678.png
# Saved spectrogram: spectrograms\non_scream\679.png
# Saved spectrogram: spectrograms\non_scream\68.png
# Saved spectrogram: spectrograms\non_scream\680.png
# Saved spectrogram: spectrograms\non_scream\681.png
# Saved spectrogram: spectrograms\non_scream\682.png
# Saved spectrogram: spectrograms\non_scream\683.png
# Saved spectrogram: spectrograms\non_scream\684.png
# Saved spectrogram: spectrograms\non_scream\685.png
# Saved spectrogram: spectrograms\non_scream\686.png
# Saved spectrogram: spectrograms\non_scream\687.png
# Saved spectrogram: spectrograms\non_scream\688.png
# Saved spectrogram: spectrograms\non_scream\689.png
# Saved spectrogram: spectrograms\non_scream\69.png
# Saved spectrogram: spectrograms\non_scream\690.png
# Saved spectrogram: spectrograms\non_scream\691.png
# Saved spectrogram: spectrograms\non_scream\692.png
# Saved spectrogram: spectrograms\non_scream\693.png
# Saved spectrogram: spectrograms\non_scream\694.png
# Saved spectrogram: spectrograms\non_scream\695.png
# Saved spectrogram: spectrograms\non_scream\696.png
# Saved spectrogram: spectrograms\non_scream\697.png
# Saved spectrogram: spectrograms\non_scream\698.png
# Saved spectrogram: spectrograms\non_scream\699.png
# Saved spectrogram: spectrograms\non_scream\7.png
# Saved spectrogram: spectrograms\non_scream\70.png
# Saved spectrogram: spectrograms\non_scream\700.png
# Saved spectrogram: spectrograms\non_scream\701.png
# Saved spectrogram: spectrograms\non_scream\702.png
# Saved spectrogram: spectrograms\non_scream\703.png
# Saved spectrogram: spectrograms\non_scream\704.png
# Saved spectrogram: spectrograms\non_scream\705.png
# Saved spectrogram: spectrograms\non_scream\706.png
# Saved spectrogram: spectrograms\non_scream\707.png
# Saved spectrogram: spectrograms\non_scream\708.png
# Saved spectrogram: spectrograms\non_scream\709.png
# Saved spectrogram: spectrograms\non_scream\71.png
# Saved spectrogram: spectrograms\non_scream\710.png
# Saved spectrogram: spectrograms\non_scream\711.png
# Saved spectrogram: spectrograms\non_scream\712.png
# Saved spectrogram: spectrograms\non_scream\713.png
# Saved spectrogram: spectrograms\non_scream\714.png
# Saved spectrogram: spectrograms\non_scream\715.png
# Saved spectrogram: spectrograms\non_scream\716.png
# Saved spectrogram: spectrograms\non_scream\717.png
# Saved spectrogram: spectrograms\non_scream\718.png
# Saved spectrogram: spectrograms\non_scream\719.png
# Saved spectrogram: spectrograms\non_scream\72.png
# Saved spectrogram: spectrograms\non_scream\720.png
# Saved spectrogram: spectrograms\non_scream\721.png
# Saved spectrogram: spectrograms\non_scream\722.png
# Saved spectrogram: spectrograms\non_scream\723.png
# Saved spectrogram: spectrograms\non_scream\724.png
# Saved spectrogram: spectrograms\non_scream\725.png
# Saved spectrogram: spectrograms\non_scream\726.png
# Saved spectrogram: spectrograms\non_scream\727.png
# Saved spectrogram: spectrograms\non_scream\728.png
# Saved spectrogram: spectrograms\non_scream\729.png
# Saved spectrogram: spectrograms\non_scream\73.png
# Saved spectrogram: spectrograms\non_scream\730.png
# Saved spectrogram: spectrograms\non_scream\731.png
# Saved spectrogram: spectrograms\non_scream\732.png
# Saved spectrogram: spectrograms\non_scream\733.png
# Saved spectrogram: spectrograms\non_scream\734.png
# Saved spectrogram: spectrograms\non_scream\735.png
# Saved spectrogram: spectrograms\non_scream\736.png
# Saved spectrogram: spectrograms\non_scream\737.png
# Saved spectrogram: spectrograms\non_scream\738.png
# Saved spectrogram: spectrograms\non_scream\739.png
# Saved spectrogram: spectrograms\non_scream\74.png
# Saved spectrogram: spectrograms\non_scream\740.png
# Saved spectrogram: spectrograms\non_scream\741.png
# Saved spectrogram: spectrograms\non_scream\742.png
# Saved spectrogram: spectrograms\non_scream\743.png
# Saved spectrogram: spectrograms\non_scream\744.png
# Saved spectrogram: spectrograms\non_scream\745.png
# Saved spectrogram: spectrograms\non_scream\746.png
# Saved spectrogram: spectrograms\non_scream\747.png
# Saved spectrogram: spectrograms\non_scream\748.png
# Saved spectrogram: spectrograms\non_scream\749.png
# Saved spectrogram: spectrograms\non_scream\75.png
# Saved spectrogram: spectrograms\non_scream\750.png
# Saved spectrogram: spectrograms\non_scream\76.png
# Saved spectrogram: spectrograms\non_scream\77.png
# Saved spectrogram: spectrograms\non_scream\78.png
# Saved spectrogram: spectrograms\non_scream\79.png
# Saved spectrogram: spectrograms\non_scream\796.png
# Saved spectrogram: spectrograms\non_scream\797.png
# Saved spectrogram: spectrograms\non_scream\798.png
# Saved spectrogram: spectrograms\non_scream\799.png
# Saved spectrogram: spectrograms\non_scream\8.png
# Saved spectrogram: spectrograms\non_scream\80.png
# Saved spectrogram: spectrograms\non_scream\800.png
# Saved spectrogram: spectrograms\non_scream\801.png
# Saved spectrogram: spectrograms\non_scream\802.png
# Saved spectrogram: spectrograms\non_scream\803.png
# Saved spectrogram: spectrograms\non_scream\804.png
# Saved spectrogram: spectrograms\non_scream\805.png
# Saved spectrogram: spectrograms\non_scream\806.png
# Saved spectrogram: spectrograms\non_scream\807.png
# Saved spectrogram: spectrograms\non_scream\808.png
# Saved spectrogram: spectrograms\non_scream\809.png
# Saved spectrogram: spectrograms\non_scream\81.png
# Saved spectrogram: spectrograms\non_scream\810.png
# Saved spectrogram: spectrograms\non_scream\811.png
# Saved spectrogram: spectrograms\non_scream\812.png
# Saved spectrogram: spectrograms\non_scream\813.png
# Saved spectrogram: spectrograms\non_scream\814.png
# Saved spectrogram: spectrograms\non_scream\815.png
# Saved spectrogram: spectrograms\non_scream\816.png
# Saved spectrogram: spectrograms\non_scream\817.png
# Saved spectrogram: spectrograms\non_scream\818.png
# Saved spectrogram: spectrograms\non_scream\819.png
# Saved spectrogram: spectrograms\non_scream\82.png
# Saved spectrogram: spectrograms\non_scream\820.png
# Saved spectrogram: spectrograms\non_scream\821.png
# Saved spectrogram: spectrograms\non_scream\822.png
# Saved spectrogram: spectrograms\non_scream\823.png
# Saved spectrogram: spectrograms\non_scream\824.png
# Saved spectrogram: spectrograms\non_scream\825.png
# Saved spectrogram: spectrograms\non_scream\826.png
# Saved spectrogram: spectrograms\non_scream\827.png
# Saved spectrogram: spectrograms\non_scream\828.png
# Saved spectrogram: spectrograms\non_scream\829.png
# Saved spectrogram: spectrograms\non_scream\83.png
# Saved spectrogram: spectrograms\non_scream\830.png
# Saved spectrogram: spectrograms\non_scream\831.png
# Saved spectrogram: spectrograms\non_scream\832.png
# Saved spectrogram: spectrograms\non_scream\833.png
# Saved spectrogram: spectrograms\non_scream\834.png
# Saved spectrogram: spectrograms\non_scream\835.png
# Saved spectrogram: spectrograms\non_scream\836.png
# Saved spectrogram: spectrograms\non_scream\837.png
# Saved spectrogram: spectrograms\non_scream\838.png
# Saved spectrogram: spectrograms\non_scream\839.png
# Saved spectrogram: spectrograms\non_scream\84.png
# Saved spectrogram: spectrograms\non_scream\840.png
# Saved spectrogram: spectrograms\non_scream\841.png
# Saved spectrogram: spectrograms\non_scream\842.png
# Saved spectrogram: spectrograms\non_scream\843.png
# Saved spectrogram: spectrograms\non_scream\844.png
# Saved spectrogram: spectrograms\non_scream\845.png
# Saved spectrogram: spectrograms\non_scream\846.png
# Saved spectrogram: spectrograms\non_scream\847.png
# Saved spectrogram: spectrograms\non_scream\848.png
# Saved spectrogram: spectrograms\non_scream\849.png
# Saved spectrogram: spectrograms\non_scream\85.png
# Saved spectrogram: spectrograms\non_scream\850.png
# Saved spectrogram: spectrograms\non_scream\851.png
# Saved spectrogram: spectrograms\non_scream\852.png
# Saved spectrogram: spectrograms\non_scream\853.png
# Saved spectrogram: spectrograms\non_scream\854.png
# Saved spectrogram: spectrograms\non_scream\855.png
# Saved spectrogram: spectrograms\non_scream\856.png
# Saved spectrogram: spectrograms\non_scream\857.png
# Saved spectrogram: spectrograms\non_scream\858.png
# Saved spectrogram: spectrograms\non_scream\859.png
# Saved spectrogram: spectrograms\non_scream\86.png
# Saved spectrogram: spectrograms\non_scream\860.png
# Saved spectrogram: spectrograms\non_scream\861.png
# Saved spectrogram: spectrograms\non_scream\862.png
# Saved spectrogram: spectrograms\non_scream\863.png
# Saved spectrogram: spectrograms\non_scream\864.png
# Saved spectrogram: spectrograms\non_scream\865.png
# Saved spectrogram: spectrograms\non_scream\866.png
# Saved spectrogram: spectrograms\non_scream\867.png
# Saved spectrogram: spectrograms\non_scream\868.png
# Saved spectrogram: spectrograms\non_scream\869.png
# Saved spectrogram: spectrograms\non_scream\87.png
# Saved spectrogram: spectrograms\non_scream\870.png
# Saved spectrogram: spectrograms\non_scream\871.png
# Saved spectrogram: spectrograms\non_scream\872.png
# Saved spectrogram: spectrograms\non_scream\873.png
# Saved spectrogram: spectrograms\non_scream\874.png
# Saved spectrogram: spectrograms\non_scream\875.png
# Saved spectrogram: spectrograms\non_scream\876.png
# Saved spectrogram: spectrograms\non_scream\877.png
# Saved spectrogram: spectrograms\non_scream\878.png
# Saved spectrogram: spectrograms\non_scream\879.png
# Saved spectrogram: spectrograms\non_scream\88.png
# Saved spectrogram: spectrograms\non_scream\880.png
# Saved spectrogram: spectrograms\non_scream\881.png
# Saved spectrogram: spectrograms\non_scream\882.png
# Saved spectrogram: spectrograms\non_scream\883.png
# Saved spectrogram: spectrograms\non_scream\884.png
# Saved spectrogram: spectrograms\non_scream\885.png
# Saved spectrogram: spectrograms\non_scream\886.png
# Saved spectrogram: spectrograms\non_scream\887.png
# Saved spectrogram: spectrograms\non_scream\888.png
# Saved spectrogram: spectrograms\non_scream\889.png
# Saved spectrogram: spectrograms\non_scream\89.png
# Saved spectrogram: spectrograms\non_scream\890.png
# Saved spectrogram: spectrograms\non_scream\891.png
# Saved spectrogram: spectrograms\non_scream\892.png
# Saved spectrogram: spectrograms\non_scream\893.png
# Saved spectrogram: spectrograms\non_scream\894.png
# Saved spectrogram: spectrograms\non_scream\895.png
# Saved spectrogram: spectrograms\non_scream\896.png
# Saved spectrogram: spectrograms\non_scream\897.png
# Saved spectrogram: spectrograms\non_scream\898.png
# Saved spectrogram: spectrograms\non_scream\899.png
# Saved spectrogram: spectrograms\non_scream\9.png
# Saved spectrogram: spectrograms\non_scream\90.png
# Saved spectrogram: spectrograms\non_scream\900.png
# Saved spectrogram: spectrograms\non_scream\901.png
# Saved spectrogram: spectrograms\non_scream\902.png
# Saved spectrogram: spectrograms\non_scream\903.png
# Saved spectrogram: spectrograms\non_scream\904.png
# Saved spectrogram: spectrograms\non_scream\905.png
# Saved spectrogram: spectrograms\non_scream\906.png
# Saved spectrogram: spectrograms\non_scream\907.png
# Saved spectrogram: spectrograms\non_scream\908.png
# Saved spectrogram: spectrograms\non_scream\909.png
# Saved spectrogram: spectrograms\non_scream\91.png
# Saved spectrogram: spectrograms\non_scream\910.png
# Saved spectrogram: spectrograms\non_scream\911.png
# Saved spectrogram: spectrograms\non_scream\912.png
# Saved spectrogram: spectrograms\non_scream\913.png
# Saved spectrogram: spectrograms\non_scream\914.png
# Saved spectrogram: spectrograms\non_scream\915.png
# Saved spectrogram: spectrograms\non_scream\916.png
# Saved spectrogram: spectrograms\non_scream\917.png
# Saved spectrogram: spectrograms\non_scream\918.png
# Saved spectrogram: spectrograms\non_scream\919.png
# Saved spectrogram: spectrograms\non_scream\92.png
# Saved spectrogram: spectrograms\non_scream\920.png
# Saved spectrogram: spectrograms\non_scream\921.png
# Saved spectrogram: spectrograms\non_scream\922.png
# Saved spectrogram: spectrograms\non_scream\923.png
# Saved spectrogram: spectrograms\non_scream\924.png
# Saved spectrogram: spectrograms\non_scream\925.png
# Saved spectrogram: spectrograms\non_scream\926.png
# Saved spectrogram: spectrograms\non_scream\927.png
# Saved spectrogram: spectrograms\non_scream\928.png
# Saved spectrogram: spectrograms\non_scream\929.png
# Saved spectrogram: spectrograms\non_scream\93.png
# Saved spectrogram: spectrograms\non_scream\930.png
# Saved spectrogram: spectrograms\non_scream\931.png
# Saved spectrogram: spectrograms\non_scream\932.png
# Saved spectrogram: spectrograms\non_scream\933.png
# Saved spectrogram: spectrograms\non_scream\934.png
# Saved spectrogram: spectrograms\non_scream\935.png
# Saved spectrogram: spectrograms\non_scream\936.png
# Saved spectrogram: spectrograms\non_scream\937.png
# Saved spectrogram: spectrograms\non_scream\938.png
# Saved spectrogram: spectrograms\non_scream\939.png
# Saved spectrogram: spectrograms\non_scream\94.png
# Saved spectrogram: spectrograms\non_scream\940.png
# Saved spectrogram: spectrograms\non_scream\941.png
# Saved spectrogram: spectrograms\non_scream\942.png
# Saved spectrogram: spectrograms\non_scream\943.png
# Saved spectrogram: spectrograms\non_scream\944.png
# Saved spectrogram: spectrograms\non_scream\945.png
# Saved spectrogram: spectrograms\non_scream\946.png
# Saved spectrogram: spectrograms\non_scream\947.png
# Saved spectrogram: spectrograms\non_scream\948.png
# Saved spectrogram: spectrograms\non_scream\949.png
# Saved spectrogram: spectrograms\non_scream\95.png
# Saved spectrogram: spectrograms\non_scream\950.png
# Saved spectrogram: spectrograms\non_scream\951.png
# Saved spectrogram: spectrograms\non_scream\952.png
# Saved spectrogram: spectrograms\non_scream\953.png
# Saved spectrogram: spectrograms\non_scream\954.png
# Saved spectrogram: spectrograms\non_scream\955.png
# Saved spectrogram: spectrograms\non_scream\956.png
# Saved spectrogram: spectrograms\non_scream\957.png
# Saved spectrogram: spectrograms\non_scream\958.png
# Saved spectrogram: spectrograms\non_scream\959.png
# Saved spectrogram: spectrograms\non_scream\96.png
# Saved spectrogram: spectrograms\non_scream\960.png
# Saved spectrogram: spectrograms\non_scream\961.png
# Saved spectrogram: spectrograms\non_scream\962.png
# Saved spectrogram: spectrograms\non_scream\963.png
# Saved spectrogram: spectrograms\non_scream\964.png
# Saved spectrogram: spectrograms\non_scream\965.png
# Saved spectrogram: spectrograms\non_scream\966.png
# Saved spectrogram: spectrograms\non_scream\967.png
# Saved spectrogram: spectrograms\non_scream\968.png
# Saved spectrogram: spectrograms\non_scream\969.png
# Saved spectrogram: spectrograms\non_scream\97.png
# Saved spectrogram: spectrograms\non_scream\970.png
# Saved spectrogram: spectrograms\non_scream\971.png
# Saved spectrogram: spectrograms\non_scream\972.png
# Saved spectrogram: spectrograms\non_scream\973.png
# Saved spectrogram: spectrograms\non_scream\974.png
# Saved spectrogram: spectrograms\non_scream\975.png
# Saved spectrogram: spectrograms\non_scream\976.png
# Saved spectrogram: spectrograms\non_scream\977.png
# Saved spectrogram: spectrograms\non_scream\978.png
# Saved spectrogram: spectrograms\non_scream\979.png
# Saved spectrogram: spectrograms\non_scream\98.png
# Saved spectrogram: spectrograms\non_scream\980.png
# Saved spectrogram: spectrograms\non_scream\981.png
# Saved spectrogram: spectrograms\non_scream\982.png
# Saved spectrogram: spectrograms\non_scream\983.png
# Saved spectrogram: spectrograms\non_scream\984.png
# Saved spectrogram: spectrograms\non_scream\985.png
# Saved spectrogram: spectrograms\non_scream\986.png
# Saved spectrogram: spectrograms\non_scream\987.png
# Saved spectrogram: spectrograms\non_scream\988.png
# Saved spectrogram: spectrograms\non_scream\989.png
# Saved spectrogram: spectrograms\non_scream\99.png
# Saved spectrogram: spectrograms\non_scream\990.png
# Saved spectrogram: spectrograms\non_scream\991.png
# Saved spectrogram: spectrograms\non_scream\992.png
# Saved spectrogram: spectrograms\non_scream\993.png
# Saved spectrogram: spectrograms\non_scream\994.png
# Saved spectrogram: spectrograms\non_scream\995.png
# Saved spectrogram: spectrograms\non_scream\996.png
# Saved spectrogram: spectrograms\non_scream\997.png
# Saved spectrogram: spectrograms\non_scream\998.png
# Saved spectrogram: spectrograms\non_scream\999.png

# %%
# Transform and load data
import torch
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor()
])

dataset = datasets.ImageFolder(spectrograms_path, transform=transform)
dataloader = torch.utils.data.DataLoader(dataset, batch_size=32, shuffle=True)

# %%
# Define the CNN model
import torch.nn as nn
class ScreamCNN(nn.Module):
    def __init__(self):
        super(ScreamCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(64 * 32 * 32, 512)
        self.fc2 = nn.Linear(512, 2)

    def forward(self, x):
        x = torch.relu(self.conv1(x))
        x = torch.max_pool2d(x, 2)
        x = torch.relu(self.conv2(x))
        x = torch.max_pool2d(x, 2)
        x = x.view(x.size(0), -1)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
# Set device, model, loss, and optimizer
import torch.optim as optim
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ScreamCNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
epochs = 20
best_val_loss = float('inf')
patience = 3  # Number of epochs to wait before stopping if validation loss doesn't improve
patience_counter = 0

for epoch in range(epochs):
    model.train()
    train_loss = 0.0

    # Training phase
    for inputs, labels in dataloader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    # Average loss for this epoch
    train_loss /= len(dataloader)
    print(f"Epoch {epoch+1}/{epochs}, Training Loss: {train_loss:.4f}")

    # Early stopping (if validation loss does not improve)
    if train_loss < best_val_loss:
        best_val_loss = train_loss
        patience_counter = 0
        # Save the model when the loss improves
        torch.save(model.state_dict(), 'best_model.pth')
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print("Early stopping: No improvement in validation loss for 3 epochs.")
            break

# Load the best model after training
model.load_state_dict(torch.load('best_model.pth'))
# Out:
# Epoch 1/20, Training Loss: 0.4292
# Epoch 2/20, Training Loss: 0.1858
# Epoch 3/20, Training Loss: 0.1383
# Epoch 4/20, Training Loss: 0.0955
# Epoch 5/20, Training Loss: 0.0759
# Epoch 6/20, Training Loss: 0.0761
# Epoch 7/20, Training Loss: 0.0448
# Epoch 8/20, Training Loss: 0.0259
# Epoch 9/20, Training Loss: 0.0431
# Epoch 10/20, Training Loss: 0.0162
# Epoch 11/20, Training Loss: 0.0228
# Epoch 12/20, Training Loss: 0.0081
# Epoch 13/20, Training Loss: 0.0040
# Epoch 14/20, Training Loss: 0.0032
# Epoch 15/20, Training Loss: 0.0004
# Epoch 16/20, Training Loss: 0.0003
# Epoch 17/20, Training Loss: 0.0001
# Epoch 18/20, Training Loss: 0.0001
# Epoch 19/20, Training Loss: 0.0001
# Epoch 20/20, Training Loss: 0.0001
# C:\Users\soham\AppData\Local\Temp\ipykernel_16556\1595429187.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('best_model.pth'))
# <All keys matched successfully>

# %%
import torch
import pyaudio
import librosa
import numpy as np
import torch.nn as nn
from torchvision import transforms
import librosa.display
import matplotlib.pyplot as plt

# PyAudio parameters
CHUNK = 1024  # Number of frames per buffer
FORMAT = pyaudio.paInt16  # Audio format
CHANNELS = 1  # Mono
RATE = 22050  # Sampling rate
DEVICE_INDEX = 0  # Select input device (0 is usually the default)

# Define the CNN model (assuming your ScreamCNN is already defined)
model = ScreamCNN().to(device)
model.eval()  # Set the model to evaluation mode

# Define the transformation for input data
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor()
])

# Initialize PyAudio
p = pyaudio.PyAudio()

def capture_audio():
    """Capture live audio from the microphone."""
    stream = p.open(format=FORMAT,
                    channels=CHANNELS,
                    rate=RATE,
                    input=True,
                    frames_per_buffer=CHUNK,
                    input_device_index=DEVICE_INDEX)
    
    print("Recording...")

    frames = []
    for _ in range(0, int(RATE / CHUNK * 1)):  # Record for 1 second
        data = stream.read(CHUNK)
        frames.append(data)
    
    print("Recording stopped.")
    stream.stop_stream()
    stream.close()
    
    audio_data = b''.join(frames)
    
    # Convert audio data from int16 to float32
    audio_data = np.frombuffer(audio_data, dtype=np.int16).astype(np.float32)
    
    # Normalize the audio data to be in the range of [-1, 1]
    audio_data /= np.max(np.abs(audio_data), axis=0)
    
    return audio_data

def audio_to_mfcc(y, sr=RATE, n_mfcc=13):
    """Convert audio to MFCC features."""
    # Librosa expects audio in float32 or float64 format, normalized to [-1, 1].
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    return mfcc

def plot_mfcc(mfcc, save_path='mfcc.png'):
    """Plot the MFCC features as a spectrogram."""
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(mfcc, x_axis='time', y_axis='mel', cmap='viridis')
    plt.colorbar(format='%+2.0f dB')
    plt.title('MFCC')
    plt.savefig(save_path)
    plt.close()

def classify_audio(mfcc):
    """Classify audio using the trained CNN model."""
    # Transform MFCC into a tensor suitable for CNN input
    mfcc_tensor = torch.tensor(mfcc).unsqueeze(0).unsqueeze(0).float().to(device)  # Adding batch and channel dimensions

    # Run the model
    with torch.no_grad():
        output = model(mfcc_tensor)
    
    # Get predicted class
    _, predicted = torch.max(output, 1)
    label = 'scream' if predicted.item() == 0 else 'non_scream'
    
    return label

def continuous_audio_detection():
    """Continuously capture audio and classify until a scream is detected."""
    while True:
        # Capture audio input
        audio_input = capture_audio()

        # Convert to MFCC
        mfcc = audio_to_mfcc(audio_input, sr=RATE)

        # Plot the MFCC spectrogram
        plot_mfcc(mfcc, save_path='live_mfcc.png')

        # Classify the audio input
        prediction = classify_audio(mfcc)
        print(f"Predicted Label: {prediction}")

        # If a scream is detected, stop the loop
        if prediction == 'scream':
            print("Scream detected! Stopping the loop.")
            break

# Start the continuous detection
continuous_audio_detection()
# Out:
# Recording...
# Recording stopped.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[25], line 112
#     109             break
#     111 # Start the continuous detection
# --> 112 continuous_audio_detection()
#
# Cell In[25], line 103, in continuous_audio_detection()
#     100 plot_mfcc(mfcc, save_path='live_mfcc.png')
#     102 # Classify the audio input
# --> 103 prediction = classify_audio(mfcc)
#     104 print(f"Predicted Label: {prediction}")
#     106 # If a scream is detected, stop the loop
#
# Cell In[25], line 82, in classify_audio(mfcc)
#      80 # Run the model
#      81 with torch.no_grad():
# ---> 82     output = model(mfcc_tensor)
#      84 # Get predicted class
#      85 _, predicted = torch.max(output, 1)
#
# File c:\Soham Joshi\5.ML Code\venv\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Soham Joshi\5.ML Code\venv\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[18], line 12, in ScreamCNN.forward(self, x)
#      11 def forward(self, x):
# ---> 12     x = torch.relu(self.conv1(x))
#      13     x = torch.max_pool2d(x, 2)
#      14     x = torch.relu(self.conv2(x))
#
# File c:\Soham Joshi\5.ML Code\venv\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Soham Joshi\5.ML Code\venv\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Soham Joshi\5.ML Code\venv\lib\site-packages\torch\nn\modules\conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Soham Joshi\5.ML Code\venv\lib\site-packages\torch\nn\modules\conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# RuntimeError: Given groups=1, weight of size [32, 3, 3, 3], expected input[1, 1, 13, 43] to have 3 channels, but got 1 channels instead
